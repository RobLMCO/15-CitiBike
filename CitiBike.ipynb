# %%
import pandas as pd
import datetime
import numpy as np
import os
import glob, os

# %%
file_2013_MaySep = os.path.join("Resources" ,"2013_MaySep.csv")
file_2013_OctDec = os.path.join("Resources" ,"2013_OctDec.csv")
file_2014_JanMar = os.path.join("Resources" ,"2014_JanMar.csv")
file_2014_AprJun = os.path.join("Resources" ,"2014_AprJun.csv")
file_2014_JulSep = os.path.join("Resources" ,"2014_JulSep.csv")
file_2014_OctDec = os.path.join("Resources" ,"2014_OctDec.csv")
file_2015_JanMar = os.path.join("Resources" ,"2015_JanMar.csv")
file_2015_AprJun = os.path.join("Resources" ,"2015_AprJun.csv")
file_2015_JulSep = os.path.join("Resources" ,"2015_JulSep.csv")
file_2015_OctDec = os.path.join("Resources" ,"2015_OctDec.csv")
file_2016_JanMar = os.path.join("Resources" ,"2016_JanMar.csv")
file_2016_AprJun = os.path.join("Resources" ,"2016_AprJun.csv")
file_2016_JulSep = os.path.join("Resources" ,"2016_JulSep.csv")
file_2016_OctDec = os.path.join("Resources" ,"2016_OctDec.csv")
file_2017_JanMar = os.path.join("Resources" ,"2017_JanMar.csv")
file_2017_AprJun = os.path.join("Resources" ,"2017_AprJun.csv")
file_2017_JulSep = os.path.join("Resources" ,"2017_JulSep.csv")
file_2017_OctDec = os.path.join("Resources" ,"2017_OctDec.csv")
file_2018_JanMar = os.path.join("Resources" ,"2018_JanMar.csv")
file_2018_AprJun = os.path.join("Resources" ,"2018_AprJun.csv")
file_2018_JulSep = os.path.join("Resources" ,"2018_JulSep.csv")
file_2018_OctDec = os.path.join("Resources" ,"2018_OctDec.csv")
file_2019_JanMar = os.path.join("Resources" ,"2019_JanMar.csv")

# %%
Data_2013Q23 = pd.read_csv(file_2013_MaySep)
Data_2013Q4 = pd.read_csv(file_2013_OctDec)
Data_2014Q1 = pd.read_csv(file_2014_JanMar)
Data_2014Q2 = pd.read_csv(file_2014_AprJun)
Data_2014Q3 = pd.read_csv(file_2014_JulSep)
Data_2014Q4 = pd.read_csv(file_2014_OctDec)
Data_2015Q1 = pd.read_csv(file_2015_JanMar)
Data_2015Q2 = pd.read_csv(file_2015_AprJun)
Data_2015Q3 = pd.read_csv(file_2015_JulSep)
Data_2015Q4 = pd.read_csv(file_2015_OctDec)
Data_2016Q1 = pd.read_csv(file_2016_JanMar)
Data_2016Q2 = pd.read_csv(file_2016_AprJun)
Data_2016Q3 = pd.read_csv(file_2016_JulSep)
Data_2016Q4 = pd.read_csv(file_2016_OctDec)
Data_2017Q1 = pd.read_csv(file_2017_JanMar)
Data_2017Q2 = pd.read_csv(file_2017_AprJun)
Data_2017Q3 = pd.read_csv(file_2017_JulSep)
Data_2017Q4 = pd.read_csv(file_2017_OctDec)
Data_2018Q1 = pd.read_csv(file_2018_JanMar)
Data_2018Q2 = pd.read_csv(file_2018_AprJun)
Data_2018Q3 = pd.read_csv(file_2018_JulSep)
Data_2018Q4 = pd.read_csv(file_2018_OctDec)
Data_2019Q1 = pd.read_csv(file_2019_JanMar)

# %%
CitibikeData_2013 = pd.concat([Data_2013Q23,Data_2013Q4],sort=False)
CitibikeData_2014 = pd.concat([Data_2014Q1,Data_2014Q2,Data_2014Q3,Data_2014Q4],sort=False)
CitibikeData_2015 = pd.concat([Data_2015Q1,Data_2015Q2,Data_2015Q3,Data_2015Q4],sort=False)
CitibikeData_2016 = pd.concat([Data_2016Q1,Data_2016Q2,Data_2016Q3,Data_2016Q4],sort=False)
CitibikeData_2017 = pd.concat([Data_2017Q1,Data_2017Q2,Data_2017Q3,Data_2017Q4],sort=False)
CitibikeData_2018 = pd.concat([Data_2018Q1,Data_2018Q2,Data_2018Q3,Data_2018Q4],sort=False)
CitibikeData_2019 = pd.concat([Data_2019Q1],sort=False)

# %%
files = glob.glob('Resources/*.csv')
dfs = [pd.read_csv(fp) for fp in files]
CitibikeData_ALL = pd.concat(dfs,sort=False)
CitibikeData_ALL.head(2118)
# Out:
#          Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0   5/27/2013                                               9767
# 1   5/28/2013                                               5215
# 2   5/29/2013                                              10981
# 3   5/30/2013                                               9850
# 4   5/31/2013                                               9253
# 5    6/1/2013                                               9852
# 6    6/2/2013                                              17590
# 7    6/3/2013                                               8599
# 8    6/4/2013                                              17589
# 9    6/5/2013                                              17433
# 10   6/6/2013                                              13732
# 11   6/7/2013                                               1393
# 12   6/8/2013                                              19899
# ...

# %%
CitibikeData_ALL.describe()
CitibikeData_ALL.to_csv('CitibikeData_ALL.csv')

# %%
CitibikeData_2013.head(219)
CitibikeData_2013.to_csv('CitibikeData_2013.csv')

# %%
CitibikeData_2014.head(365)
CitibikeData_2014.to_csv('CitibikeData_2014.csv')

# %%
CitibikeData_2015.head(365)
CitibikeData_2015.to_csv('CitibikeData_2015.csv')

# %%
CitibikeData_2016.head(366)
CitibikeData_2016.to_csv('CitibikeData_2016.csv')

# %%
CitibikeData_2017.head(365)
CitibikeData_2017.to_csv('CitibikeData_2017.csv')

# %%
CitibikeData_2018.head(365)
CitibikeData_2018.to_csv('CitibikeData_2018.csv')

# %%
CitibikeData_2019.head(73)
CitibikeData_2019.to_csv('CitibikeData_2019.csv')

# %%
tripfiles = glob.glob('Resources/Trips/*.csv')
trip_dfs = [pd.read_csv(fp) for fp in tripfiles]
CititripData_2018 = pd.concat(trip_dfs,sort=False)

# %%
CititripData_2018.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1           723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2           496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3           306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4           306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
#
#    start station id start station name  start station latitude  \
# 0              72.0   W 52 St & 11 Ave               40.767272
# 1              72.0   W 52 St & 11 Ave               40.767272
# 2              72.0   W 52 St & 11 Ave               40.767272
# 3              72.0   W 52 St & 11 Ave               40.767272
# 4              72.0   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id         end station name  \
# 0               -73.993929           505.0          6 Ave & W 33 St
# ...

# %%
CititripData_2018.to_csv('CititripData_2018.csv')

# %%
CititripData_2018.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  1.194388e+07      1.194299e+07            1.194388e+07
# mean   9.356075e+02      1.220109e+03            4.073627e+01
# std    1.856057e+04      1.319170e+03            2.958349e-02
# min    6.100000e+01      7.200000e+01            4.064654e+01
# 25%    3.540000e+02      3.470000e+02            4.071775e+01
# 50%    5.920000e+02      4.690000e+02            4.073705e+01
# 75%    1.025000e+03      3.096000e+03            4.075500e+01
# max    1.951005e+07      3.721000e+03            4.550636e+01
#
#        start station longitude  end station id  end station latitude  \
# count             1.194388e+07    1.194299e+07          1.194388e+07
# mean             -7.398500e+01    1.442161e+03          4.073631e+01
# std               1.756079e-02    1.404423e+03          3.008884e-02
# min              -7.402535e+01    7.200000e+01          4.064654e+01
# ...
